# %%
# %load_ext autoreload
import os
# %autoreload 2
# %aimport lasagne.datasets.infinite_image_dataset
# %aimport lasagne.easy
import theano.sandbox.cuda
theano.sandbox.cuda.use("gpu0")


from lasagne import easy
import lasagne
import lasagne.data

# currently available datasets:
from lasagne.datasets import mnist, fonts, notmnist, insects, ilc, infinite_image_dataset


import theano.tensor as T
import theano
import os
import numpy as np
import time
import seaborn as sbn
import copy

from lasagne.layers.dense import DenseLayer
from lasagne.layers.base import Layer

from pylearn2.scripts.plot_weights import (grid_plot, 
                                           build_visualizations_by_weighted_combinations)

import matplotlib.pyplot as plt

from sklearn import cross_validation

# %matplotlib inline

from theano.sandbox.rng_mrg import MRG_RandomStreams

# init a random number generator
rng =  MRG_RandomStreams(111222333)
# Out:
# WARNING (theano.sandbox.cuda): Ignoring call to use(0), GPU number 1 is already in use.
# WARNING:theano.sandbox.cuda:Ignoring call to use(0), GPU number 1 is already in use.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def build_model(x_dim, num_hidden_list, y_dim, tied_weights=True):
    
    """
    This function builds a deep auto-encoder model reconstructing the input
    and in the same time predicting the labels.
    
    x_dim : dimensionality of the input
    y_dim : dimensionality of the output
    num_hidden_list : list of nb of hidden units of each layer         
    """
    l_x_in = lasagne.layers.InputLayer(
            shape=(None, x_dim),
        )
    l_y_in = lasagne.layers.InputLayer(
            shape=(None, y_dim),
        )

    
    
    # 1) First part of the auto-encoder : encoding part
    
    cur_layer = l_x_in
    weights = []
    for i, num_hidden in enumerate(num_hidden_list): # ?? num_hidden est 
                                            #le nbr de couches cachées? modifié : num_hidden_list est une liste
                                            # contenant le nombre d'unités dans 
                                            # chaque couche cachée 
        #lasagne.init.Uniform() use by default the Glorot et al initiliazition 
        # which works well for images (http://jmlr.org/proceedings/papers/v9/glorot10a/glorot10a.pdf)
        # alternatives : Normal(), Orthogonal(), Sparse(sparsity coef, standard dev of units)
        
        W = lasagne.init.Uniform()
        
        
        # Fill the biases with zero
        b = lasagne.init.Constant(0.)
        
        nonlinearity = lasagne.nonlinearities.sigmoid
            
        cur_layer = lasagne.layers.DenseLayer(
            cur_layer,
            num_units=num_hidden,
            nonlinearity=nonlinearity,
            W=W,
            b=b
        )
        weights.append(cur_layer.W)
    
    l_code = cur_layer # l_code is the topest layer of the encoder

    # 2) second part of the auto-encoder : the decoder
    num_hidden_list_backward = list(reversed(num_hidden_list))[1:]
    
    for i, num_hidden in enumerate(num_hidden_list_backward  + [x_dim] ):
        
        if tied_weights == True:            
            W = (weights[len(num_hidden_list) - i - 1].T)
        else:
            W = lasagne.init.Uniform()
        
        b = lasagne.init.Constant(0.)
        
        nonlinearity = lasagne.nonlinearities.sigmoid
        
        
        cur_layer = DenseLayer(
            cur_layer,
            num_units=num_hidden,
            nonlinearity=nonlinearity,
            W=W,
            b=b,
            tied_weights=tied_weights
        )
    
    
    # l_x_hat is the reconstruction layer : ^(x)
    l_x_hat = cur_layer
    
    # 3) a layer predicting the labels from the code
    
    
    # l_y_hat is the  layer of label predictions
    l_y_hat = lasagne.layers.DenseLayer( ## ?? C'est quoi denselayer?
                                        ## fully connected? Oui dense  = fully connected
        l_code,
        num_units = y_dim,
        nonlinearity=lasagne.nonlinearities.tanh
    )

    return l_x_in, l_y_in, l_code, l_x_hat, l_y_hat


# the function that sets the loss function to minimize
def objective(X_batch, y_batch, x_hat, y_hat, prediction_coeficient=0):
    """
        X_batch : the given input
        y_batch : the given output
        x_hat : the reconstructed input
        y_hat : the predicted labels
        
    """
    
    # minimize cross-entropy (for reconstruction)
    L = -( (X_batch * T.log(x_hat) + (1 - X_batch) * T.log(1 - x_hat)))
    reconstruction_loss = T.mean(  T.sum(L, axis=1)   )
    #reconstruction_loss = T.mean(L)
    #econstruction_loss = -T.mean(L)
    #reconstruction_loss = T.mean(   T.sum((X_batch - x_hat)**2, axis=1)  )
    # minimize the prediction error
    prediction_loss = T.mean(T.sum( (y_batch - y_hat)**2, axis=1 ))
    return reconstruction_loss + prediction_loss * prediction_coeficient

# Zero-Masking noise : corruption_level is the ratio by which we corrupt, 0.2 means
# 0.2 of the pixels will be randomly set to zero for each example
def corrupted_zero_masking(rng, x, corruption_level):
    return x * rng.binomial(size=x.shape, n=1, p=1 - corruption_level, dtype=theano.config.floatX)

# Salt And pepper noise : a subset of pixels are selected randomly and transformed fairly into 1 or 0
def corrupted_salt_and_pepper(rng, x, corruption_level):
    selected = rng.binomial(size=x.shape, n=1, p=corruption_level, dtype=theano.config.floatX)
    return x * (1 - selected) + selected * rng.binomial(size=x.shape, n=1, p=0.5, dtype=theano.config.floatX)

# %%
class Experiment(lasagne.easy.Experiment):
    """
    An experiment is an object doing all the steps we need:
    
      - 1) incorporating the dataset
      - 2) setting up the hyper-parameters
      - 3) building the model
      - 4) run it
      - 5) collect statistics and do some visualizations
    """

    def __init__(self, x_hidden_units):
        self.x_hidden_units = x_hidden_units
        self.rng = rng
        self.stats = []
    
    # - format the data so that labels are one-hot vectors instead of numbers
    # - set the train, valid and test set
    def load_data(self, datasets):
        self.train, self.valid, self.test =  datasets["train"], datasets["valid"], datasets["test"]
    
    # initialize the hyper-parameters
    def set_hp(self, hp=None):
        if hp is None:
            hp = {}
        self.learning_rate = hp.get("learning_rate", 0.1)
        self.momentum = hp.get("momentum", 0.)
# ?? what does the next to line do? - I dont get the syntax (don't understand )
# it gets the dimensionality of the input from the dataset matrix (shape[1] is the number of columns)
        self.input_dim = self.train.X.get_value().shape[1]
        self.output_dim  = self.train.y.get_value().shape[1]
        self.batch_size = hp.get("batch_size", 20)
        self.nb_batches = self.train.X.get_value().shape[0] // self.batch_size
        self.nb_epochs = hp.get("nb_epochs", 15)
        self.corruption = hp.get("corruption", 0.3)
        self.prediction_coeficient = hp.get("prediction_coeficient", 0.)
        self.generate_each_epoch = hp.get("generate_each_epoch", False)
    
    def build_model(self):
        
        self.batch_index, self.X_batch, self.y_batch, self.batch_slice = easy.get_theano_batch_variables(self.batch_size, 
                                                                                                         y_softmax=False)
        

        # creates the model
        self.l_x_in, self.l_y_in, self.l_code, self.l_x_hat, self.l_y_hat = build_model(self.input_dim, 
                                                                                        self.x_hidden_units,
                                                                                        self.output_dim)
        
        # get the corrupted version of the input
        self.corrupted_X_batch = corrupted_zero_masking(self.rng, self.X_batch, self.corruption)


        # get the loss function
        self.loss = objective(self.X_batch,
                              self.y_batch,
                              self.l_x_hat.get_output(self.corrupted_X_batch), # the reconstruction from the corrupted input,
                              self.l_y_hat.get_output({self.l_x_in : self.X_batch, 
                                                       self.l_y_in : self.y_batch} ),# the prediction label
                              prediction_coeficient=self.prediction_coeficient) 
        
        # the predictions
        pred = T.argmax(self.l_y_hat.get_output({self.l_x_in : self.X_batch, self.l_y_in : self.y_batch}),
                        axis=1)
        # the accuracy
        accuracy = T.mean(T.eq(pred, T.argmax(self.y_batch, axis=1)))
        #reconstruction_error =  T.mean( T.sum( T.abs_(self.l_x_hat.get_output(self.X_batch) - self.X_batch), axis=1 ) )
        z = self.l_x_hat.get_output(self.X_batch)
        x = self.X_batch
        L = - T.sum(x * T.log(z) + (1 - x) * T.log(1 - z), axis=1)
        reconstruction_error = T.mean(L)

        # a function that computes the loss
        self.get_loss = theano.function([self.X_batch, self.y_batch], self.loss)
        # a function that get the reconstructions
        self.get_reconstruction = theano.function([self.X_batch],
                                                   self.l_x_hat.get_output(self.X_batch))
        self.get_reconstruction_error = theano.function([self.X_batch],
                                                        reconstruction_error)
        
        code = T.matrix('code')
        self.get_reconstruction_from_code = theano.function([code],
                                                             self.l_x_hat.get_output({self.l_code : code}) )
        
        # a function that gets the code
        self.get_code = theano.function([self.X_batch], self.l_code.get_output(self.X_batch))
        
        # a function that gets the accuracy                  
        self.get_accuracy = theano.function([self.X_batch, self.y_batch], accuracy)
        

        # get the gradient updates
        all_params = lasagne.layers.get_all_params(self.l_x_hat)
        
        # uses adadelta as on optimization procedure (http://www.matthewzeiler.com/pubs/googleTR2012/googleTR2012.pdf)
        #self.updates = lasagne.updates.adadelta(self.loss, all_params, learning_rate=self.learning_rate)
        self.updates = lasagne.updates.nesterov_momentum(self.loss, all_params, learning_rate=self.learning_rate,
                                                         momentum=self.momentum)

        # get the iteration update
        self.iter_update_batch = easy.get_iter_update_supervision(self.train.X, self.train.y, self.X_batch, self.y_batch,
                                                                  self.loss, self.updates,
                                                                  self.batch_index, self.batch_slice)
        
        
    def run(self):
        train, valid, test = self.train, self.valid, self.test

        def iter_update(epoch):
            """
            - this function is called in each epoch
            - it returns (in each epoch) an update status : it is a dict containing 
              the loss, accuracy, reconstruction error of train, valid and test sets
            """
            if self.generate_each_epoch == True:
                train.load()
                train.X = theano.shared(train.X)
                train.y = theano.shared(train.y)
    
            # for each batch, update the parameters
            for i in xrange(self.nb_batches):
                self.iter_update_batch(i)

            # get the loss of train, valid  and test sets
            ds = {"train": train, "valid": valid, "test": test}
            status = {}
            for k, v in ds.items():
                X, y = v.X.get_value(), v.y.get_value()
                status["loss_" + k] = self.get_loss(X, y)
                status["accuracy_" + k] = self.get_accuracy(X, y)
                status["reconstruction_error_" + k] = self.get_reconstruction_error(X)
                
            status["epoch"] = epoch
            return status

        def quitter(update_status):
            """
                in each epoch quitter is called to check if the program will stop before reaching the
                given number of epochs
            """
            
            # here we don't stop
            return False

        def monitor(update_status):
            """
                in each epoch, get the update_status from iter_update.
                returns the monitor output which will be communicated to the observer.
            """
            self.stats.append(update_status)
            return update_status
        
        
        def observer(monitor_output):
            """
                get the status of the current epoch from the monitor and shows it
            """
            if monitor_output["epoch"] % 20 == 0:
                for k, v in monitor_output.items():
                    print("%s : %f" % (k, v))
        
        
        # train the model
        lasagne.easy.main_loop(self.nb_epochs, iter_update, quitter, monitor, observer)
    
    # after training the model, show the reconstructions
    def post_show_reconstructions(self, nb=30):
        x = easy.get_2d_square_image_view(self.train.X.get_value())
        x_rec = self.get_reconstruction(self.train.X.get_value())
        x_rec = easy.get_2d_square_image_view(x_rec)
        
        indices = np.random.randint(0, x.shape[0] - 1, size=(nb,))

        k = 1
        for i in xrange(nb):
            plt.subplot(nb, 2, k)
            plt.axis('off')
            plt.imshow(x[indices[i]], cmap='gray')
            k += 1
            plt.subplot(nb, 2, k)
            plt.axis('off')
            plt.imshow(x_rec[indices[i]], cmap='gray')
            k += 1
        plt.show()

# %%
layerwise_autoencoders_hidden = [256, 100, 50, 25]

# Load  dataset
dataset = lasagne.datasets.fonts.Fonts(kind='all_32', labels_kind='letters') # change by lasagne.datasets.datasets.mnist.MNIST
                                         # or by lasagne.datasets.fonts.Fonts with (kind='all_32', labels_kind='letters')
                                         # or by lasagne.datasets.notmnist.NotMNIST
                                         # or by lasagne.datasets.insects.Insects 
                                         # or by lasagne.datasets.ilc.ILC
dataset.load()
dataset.y = lasagne.utils.floatX(lasagne.easy.to_hamming(dataset.y, presence=1, absence=-1))


data_is_generated = False # make it True if you want to use InfiniteImageDataset
    
#mean = dataset.X.mean(axis=0)[np.newaxis, :]
#std = dataset.X.std(axis=0)[np.newaxis, :] 
# standardize
#dataset.X = (dataset.X - mean) / (std + (std==0))
# Split
X_train, X_test, y_train, y_test = cross_validation.train_test_split(dataset.X, dataset.y, test_size=0.25)
X_train, X_valid, y_train, y_valid = cross_validation.train_test_split(X_train, y_train, test_size=0.25)




X_train = theano.shared(X_train)
X_valid = theano.shared(X_valid)
X_test = theano.shared(X_test)
y_train = theano.shared(y_train)
y_valid = theano.shared(y_valid)
y_test = theano.shared(y_test)


datasets = {"train" : lasagne.data.Dataset(X_train, y_train), 
            "valid": lasagne.data.Dataset(X_valid, y_valid),
            "test": lasagne.data.Dataset(X_test, y_test)}

params = {}


# InfiniteImageDataset
if data_is_generated:
    X_initial = dataset.X[2:3]
    y_initial = dataset.y[2:3]
    nb_examples = {
        "train": 500,
        "valid": 100,
        "test": 100
    }
    params = {
        "x_translate_max":1, 
        "y_translate_max":1, 
        "theta_range":(-np.pi / 5, np.pi / 5),
        "rgb": False
    }
    for name, ds in datasets.items():
        X, y = ds.X.get_value(), ds.y.get_value()
        ds = datasets[name] = infinite_image_dataset.InfiniteImageDataset(X_initial, y_initial, nb_examples[name], params)
        ds.load()
        ds.X = theano.shared(ds.X)
        ds.y = theano.shared(ds.y)

# %%
# Visualize the dataset
grid_plot(lasagne.easy.get_2d_square_image_view(datasets['train'].X.get_value()), nbrows=10, nbcols=10, random=True)

# %%
# un experiment c'est un entrainment d'un auto-encoder.
# dans chaque experiment on entraine un auto-encoder pour reconstruire la couche precedente (greedy layer-wise auto-encoders)
# apres chaque expriment on transforme le dataset en utilisant l'auto-encoder qu'on a entrainé
# On garde les data générés pour chaque couche

# ?? que veut dire: reconstruction_error_wrong_pixels_per_example_train, rennomée en reconstruction_error
# je voulais juste dire que c'est le nombre de pixels erronés en moyenne pour chaque exemple

# initialize the experiments
reconstruct_previous_layer_experiments = []
for nb_hidden in layerwise_autoencoders_hidden:
    exp = Experiment([nb_hidden])
    reconstruct_previous_layer_experiments.append(exp)

cur_datasets = datasets
for i, exp in enumerate(reconstruct_previous_layer_experiments):
    print "Training the layer %d" % (i,)
    # Reconstruct the previous layer (for the first experiment, reconstruct the input)
    exp.load_data(cur_datasets)
    hp = {
        "nb_epochs": 200,
        "corruption": 0.3,
        "batch_size": 20,
        "learning_rate": 0.1,
        "momentum": 0.5,
        # predict the labels only for the last layer
        "prediction_coeficient" :  (0.1 if i == len(reconstruct_previous_layer_experiments)-1 else 0.),
        # Used to generate dataset in each epoch (InfiniteImageDataset)
        "generate_each_epoch" : True if (i == 0 and data_is_generated) else False
    }
    exp.set_hp(hp)
    exp.build_model()
    exp.run()
    # transform the datasets splits using the new learned auto-encoder
    new_datasets = {}
    for name, dataset in cur_datasets.items():
        X, y = dataset.X, dataset.y
        X = theano.shared(exp.get_code(X.get_value()))
        new_datasets[name] = lasagne.data.Dataset(X, y)
    cur_datasets = new_datasets
# Out:
# Training the layer 0
# accuracy_train : 0.036345
# loss_test : 4.043675
# reconstruction_error_test : 4.034677
# loss_valid : 4.026902
# loss_train : 4.000890
# epoch : 0.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.992651
# reconstruction_error_valid : 4.018303
# accuracy_train : 0.036345
# loss_test : 4.029954
# reconstruction_error_test : 4.020546
# loss_valid : 4.013120
# loss_train : 3.987111
# epoch : 20.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.978442
# reconstruction_error_valid : 4.004131
# accuracy_train : 0.036345
# loss_test : 4.027108
# reconstruction_error_test : 4.017312
# loss_valid : 4.010304
# loss_train : 3.984280
# epoch : 40.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.975310
# reconstruction_error_valid : 4.000934
# accuracy_train : 0.036345
# loss_test : 4.024093
# reconstruction_error_test : 4.014162
# loss_valid : 4.007419
# loss_train : 3.981350
# epoch : 60.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.972241
# reconstruction_error_valid : 3.997803
# accuracy_train : 0.036345
# loss_test : 4.020861
# reconstruction_error_test : 4.011030
# loss_valid : 4.004206
# loss_train : 3.978319
# epoch : 80.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.969161
# reconstruction_error_valid : 3.994678
# accuracy_train : 0.036345
# loss_test : 4.017696
# reconstruction_error_test : 4.007782
# loss_valid : 4.000995
# loss_train : 3.975056
# epoch : 100.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.965930
# reconstruction_error_valid : 3.991424
# accuracy_train : 0.036345
# loss_test : 4.013984
# reconstruction_error_test : 4.004195
# loss_valid : 3.997416
# loss_train : 3.971359
# epoch : 120.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.962316
# reconstruction_error_valid : 3.987822
# accuracy_train : 0.036345
# loss_test : 4.009087
# reconstruction_error_test : 3.999458
# loss_valid : 3.992411
# loss_train : 3.966560
# epoch : 140.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.957483
# reconstruction_error_valid : 3.983069
# accuracy_train : 0.036345
# loss_test : 4.001626
# reconstruction_error_test : 3.991968
# loss_valid : 3.985156
# loss_train : 3.959056
# epoch : 160.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.949768
# reconstruction_error_valid : 3.975571
# accuracy_train : 0.036345
# loss_test : 3.989873
# reconstruction_error_test : 3.981121
# loss_valid : 3.973312
# loss_train : 3.946832
# epoch : 180.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.938478
# reconstruction_error_valid : 3.964657
# accuracy_train : 0.036345
# loss_test : 3.974972
# reconstruction_error_test : 3.973215
# loss_valid : 3.958470
# loss_train : 3.931606
# epoch : 200.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.929876
# reconstruction_error_valid : 3.956270
# accuracy_train : 0.036345
# loss_test : 3.963120
# reconstruction_error_test : 3.977106
# loss_valid : 3.946714
# loss_train : 3.919468
# epoch : 220.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.933022
# reconstruction_error_valid : 3.958977
# accuracy_train : 0.036345
# loss_test : 3.956281
# reconstruction_error_test : 3.983842
# loss_valid : 3.939498
# loss_train : 3.912351
# epoch : 240.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.939320
# reconstruction_error_valid : 3.964542
# accuracy_train : 0.036345
# loss_test : 3.951635
# reconstruction_error_test : 3.986547
# loss_valid : 3.934957
# loss_train : 3.907894
# epoch : 260.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.941914
# reconstruction_error_valid : 3.966618
# accuracy_train : 0.036345
# loss_test : 3.948143
# reconstruction_error_test : 3.986964
# loss_valid : 3.931269
# loss_train : 3.904239
# epoch : 280.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.942369
# reconstruction_error_valid : 3.966756
# accuracy_train : 0.036345
# loss_test : 3.944839
# reconstruction_error_test : 3.984363
# loss_valid : 3.928001
# loss_train : 3.901022
# epoch : 300.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.939889
# reconstruction_error_valid : 3.964090
# accuracy_train : 0.036345
# loss_test : 3.941619
# reconstruction_error_test : 3.983238
# loss_valid : 3.924671
# loss_train : 3.897888
# epoch : 320.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.938851
# reconstruction_error_valid : 3.962851
# accuracy_train : 0.036345
# loss_test : 3.938197
# reconstruction_error_test : 3.979187
# loss_valid : 3.921106
# loss_train : 3.894493
# epoch : 340.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.934942
# reconstruction_error_valid : 3.958796
# accuracy_train : 0.036345
# loss_test : 3.934308
# reconstruction_error_test : 3.974157
# loss_valid : 3.917310
# loss_train : 3.890670
# epoch : 360.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.930041
# reconstruction_error_valid : 3.953747
# accuracy_train : 0.036345
# loss_test : 3.929994
# reconstruction_error_test : 3.971205
# loss_valid : 3.912588
# loss_train : 3.886305
# epoch : 380.000000
# accuracy_valid : 0.041063
# accuracy_test : 0.041184
# reconstruction_error_train : 3.927138
# reconstruction_error_valid : 3.950617
# Training the layer 1
# accuracy_train : 0.039529
# loss_test : 104.142891
# reconstruction_error_test : 106.214821
# loss_valid : 104.175194
# loss_train : 104.212250
# epoch : 0.000000
# accuracy_valid : 0.036448
# accuracy_test : 0.037603
# reconstruction_error_train : 106.285873
# reconstruction_error_valid : 106.249367
# accuracy_train : 0.056136
# loss_test : 104.132240
# reconstruction_error_test : 105.039116
# loss_valid : 104.166359
# loss_train : 104.202141
# epoch : 20.000000
# accuracy_valid : 0.053796
# accuracy_test : 0.047153
# reconstruction_error_train : 105.106178
# reconstruction_error_valid : 105.071640
# accuracy_train : 0.049345
# loss_test : 104.128998
# reconstruction_error_test : 104.929375
# loss_valid : 104.163231
# loss_train : 104.199066
# epoch : 40.000000
# accuracy_valid : 0.049180
# accuracy_test : 0.042617
# reconstruction_error_train : 104.995888
# reconstruction_error_valid : 104.961685
# accuracy_train : 0.039529
# loss_test : 104.125580
# reconstruction_error_test : 104.907852
# loss_valid : 104.159012
# loss_train : 104.194611
# epoch : 60.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.973755
# reconstruction_error_valid : 104.939781
# accuracy_train : 0.039529
# loss_test : 104.124390
# reconstruction_error_test : 104.840080
# loss_valid : 104.159340
# loss_train : 104.194855
# epoch : 80.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.905960
# reconstruction_error_valid : 104.872116
# accuracy_train : 0.039529
# loss_test : 104.124367
# reconstruction_error_test : 104.764885
# loss_valid : 104.159142
# loss_train : 104.194214
# epoch : 100.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.830734
# reconstruction_error_valid : 104.796913
# accuracy_train : 0.039529
# loss_test : 104.123398
# reconstruction_error_test : 104.730621
# loss_valid : 104.156914
# loss_train : 104.192871
# epoch : 120.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.796005
# reconstruction_error_valid : 104.762466
# accuracy_train : 0.039529
# loss_test : 104.122269
# reconstruction_error_test : 104.677505
# loss_valid : 104.155716
# loss_train : 104.191811
# epoch : 140.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.742790
# reconstruction_error_valid : 104.709312
# accuracy_train : 0.039529
# loss_test : 104.122383
# reconstruction_error_test : 104.621071
# loss_valid : 104.155518
# loss_train : 104.191284
# epoch : 160.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.686363
# reconstruction_error_valid : 104.653015
# accuracy_train : 0.039529
# loss_test : 104.121384
# reconstruction_error_test : 104.583755
# loss_valid : 104.155403
# loss_train : 104.191719
# epoch : 180.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.648872
# reconstruction_error_valid : 104.615639
# accuracy_train : 0.039529
# loss_test : 104.119476
# reconstruction_error_test : 104.539070
# loss_valid : 104.153755
# loss_train : 104.190346
# epoch : 200.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.604187
# reconstruction_error_valid : 104.571037
# accuracy_train : 0.039529
# loss_test : 104.119850
# reconstruction_error_test : 104.503220
# loss_valid : 104.153328
# loss_train : 104.190063
# epoch : 220.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.568169
# reconstruction_error_valid : 104.535042
# accuracy_train : 0.039529
# loss_test : 104.119080
# reconstruction_error_test : 104.482315
# loss_valid : 104.153069
# loss_train : 104.189964
# epoch : 240.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.547302
# reconstruction_error_valid : 104.514229
# accuracy_train : 0.039529
# loss_test : 104.120087
# reconstruction_error_test : 104.459457
# loss_valid : 104.152603
# loss_train : 104.189728
# epoch : 260.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.524330
# reconstruction_error_valid : 104.491318
# accuracy_train : 0.039529
# loss_test : 104.119583
# reconstruction_error_test : 104.435822
# loss_valid : 104.154114
# loss_train : 104.189682
# epoch : 280.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.500877
# reconstruction_error_valid : 104.467842
# accuracy_train : 0.039529
# loss_test : 104.118744
# reconstruction_error_test : 104.418404
# loss_valid : 104.150742
# loss_train : 104.188255
# epoch : 300.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.483406
# reconstruction_error_valid : 104.450401
# accuracy_train : 0.039529
# loss_test : 104.118721
# reconstruction_error_test : 104.418617
# loss_valid : 104.151718
# loss_train : 104.188797
# epoch : 320.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.483521
# reconstruction_error_valid : 104.450562
# accuracy_train : 0.039529
# loss_test : 104.119072
# reconstruction_error_test : 104.421844
# loss_valid : 104.152695
# loss_train : 104.189980
# epoch : 340.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.486603
# reconstruction_error_valid : 104.453682
# accuracy_train : 0.039529
# loss_test : 104.118355
# reconstruction_error_test : 104.395935
# loss_valid : 104.152634
# loss_train : 104.188293
# epoch : 360.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.460922
# reconstruction_error_valid : 104.427917
# accuracy_train : 0.039529
# loss_test : 104.117836
# reconstruction_error_test : 104.368111
# loss_valid : 104.152534
# loss_train : 104.188293
# epoch : 380.000000
# accuracy_valid : 0.040586
# accuracy_test : 0.034380
# reconstruction_error_train : 104.433258
# reconstruction_error_valid : 104.400208
# Training the layer 2
# accuracy_train : 0.037778
# loss_test : 21.341303
# reconstruction_error_test : 21.478256
# loss_valid : 21.325676
# loss_train : 21.314438
# epoch : 0.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.452417
# reconstruction_error_valid : 21.463234
# accuracy_train : 0.037778
# loss_test : 21.321243
# reconstruction_error_test : 21.477818
# loss_valid : 21.305748
# loss_train : 21.294146
# epoch : 20.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.450459
# reconstruction_error_valid : 21.461857
# accuracy_train : 0.037778
# loss_test : 21.319038
# reconstruction_error_test : 21.479527
# loss_valid : 21.303900
# loss_train : 21.292116
# epoch : 40.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.451975
# reconstruction_error_valid : 21.463097
# accuracy_train : 0.037778
# loss_test : 21.318605
# reconstruction_error_test : 21.465385
# loss_valid : 21.303301
# loss_train : 21.291290
# epoch : 60.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.437847
# reconstruction_error_valid : 21.448965
# accuracy_train : 0.037778
# loss_test : 21.318382
# reconstruction_error_test : 21.466986
# loss_valid : 21.302710
# loss_train : 21.290939
# epoch : 80.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.439453
# reconstruction_error_valid : 21.450577
# accuracy_train : 0.037778
# loss_test : 21.317875
# reconstruction_error_test : 21.463224
# loss_valid : 21.302980
# loss_train : 21.290836
# epoch : 100.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.435698
# reconstruction_error_valid : 21.446836
# accuracy_train : 0.037778
# loss_test : 21.318130
# reconstruction_error_test : 21.456337
# loss_valid : 21.302542
# loss_train : 21.290955
# epoch : 120.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.428833
# reconstruction_error_valid : 21.439987
# accuracy_train : 0.037778
# loss_test : 21.318001
# reconstruction_error_test : 21.475334
# loss_valid : 21.302702
# loss_train : 21.290804
# epoch : 140.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.447802
# reconstruction_error_valid : 21.458935
# accuracy_train : 0.037778
# loss_test : 21.317869
# reconstruction_error_test : 21.466438
# loss_valid : 21.302746
# loss_train : 21.290819
# epoch : 160.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.438908
# reconstruction_error_valid : 21.450071
# accuracy_train : 0.037778
# loss_test : 21.317938
# reconstruction_error_test : 21.453810
# loss_valid : 21.302752
# loss_train : 21.290916
# epoch : 180.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.426348
# reconstruction_error_valid : 21.437550
# accuracy_train : 0.037778
# loss_test : 21.318113
# reconstruction_error_test : 21.461159
# loss_valid : 21.302557
# loss_train : 21.290550
# epoch : 200.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.433670
# reconstruction_error_valid : 21.444872
# accuracy_train : 0.037778
# loss_test : 21.317688
# reconstruction_error_test : 21.464226
# loss_valid : 21.302225
# loss_train : 21.290384
# epoch : 220.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.436745
# reconstruction_error_valid : 21.447958
# accuracy_train : 0.037778
# loss_test : 21.317604
# reconstruction_error_test : 21.459700
# loss_valid : 21.302317
# loss_train : 21.290611
# epoch : 240.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.432259
# reconstruction_error_valid : 21.443491
# accuracy_train : 0.037778
# loss_test : 21.317741
# reconstruction_error_test : 21.451012
# loss_valid : 21.302179
# loss_train : 21.290714
# epoch : 260.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.423590
# reconstruction_error_valid : 21.434849
# accuracy_train : 0.037778
# loss_test : 21.317308
# reconstruction_error_test : 21.455660
# loss_valid : 21.302275
# loss_train : 21.290504
# epoch : 280.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.428236
# reconstruction_error_valid : 21.439505
# accuracy_train : 0.037778
# loss_test : 21.317698
# reconstruction_error_test : 21.453241
# loss_valid : 21.302713
# loss_train : 21.290417
# epoch : 300.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.425829
# reconstruction_error_valid : 21.437107
# accuracy_train : 0.037778
# loss_test : 21.317961
# reconstruction_error_test : 21.449919
# loss_valid : 21.302612
# loss_train : 21.290260
# epoch : 320.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.422510
# reconstruction_error_valid : 21.433802
# accuracy_train : 0.037778
# loss_test : 21.317467
# reconstruction_error_test : 21.459446
# loss_valid : 21.302031
# loss_train : 21.290007
# epoch : 340.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.432032
# reconstruction_error_valid : 21.443325
# accuracy_train : 0.037778
# loss_test : 21.317503
# reconstruction_error_test : 21.461477
# loss_valid : 21.302164
# loss_train : 21.290127
# epoch : 360.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.434084
# reconstruction_error_valid : 21.445383
# accuracy_train : 0.037778
# loss_test : 21.317547
# reconstruction_error_test : 21.463032
# loss_valid : 21.302231
# loss_train : 21.290173
# epoch : 380.000000
# accuracy_valid : 0.040745
# accuracy_test : 0.038319
# reconstruction_error_train : 21.435656
# reconstruction_error_valid : 21.446960
# Training the layer 3
# accuracy_train : 0.032154
# loss_test : 32.784473
# reconstruction_error_test : 30.942272
# loss_valid : 32.791698
# loss_train : 32.799122
# epoch : 0.000000
# accuracy_valid : 0.037084
# accuracy_test : 0.035096
# reconstruction_error_train : 30.954855
# reconstruction_error_valid : 30.950247
# accuracy_train : 0.037619
# loss_test : 32.769760
# reconstruction_error_test : 30.919876
# loss_valid : 32.777172
# loss_train : 32.784698
# epoch : 20.000000
# accuracy_valid : 0.039790
# accuracy_test : 0.039035
# reconstruction_error_train : 30.932636
# reconstruction_error_valid : 30.928040
# accuracy_train : 0.037619
# loss_test : 32.769897
# reconstruction_error_test : 30.932497
# loss_valid : 32.776211
# loss_train : 32.784321
# epoch : 40.000000
# accuracy_valid : 0.039790
# accuracy_test : 0.039035
# reconstruction_error_train : 30.945166
# reconstruction_error_valid : 30.940613
# accuracy_train : 0.037619
# loss_test : 32.769436
# reconstruction_error_test : 30.927692
# loss_valid : 32.776108
# loss_train : 32.784203
# epoch : 60.000000
# accuracy_valid : 0.039790
# accuracy_test : 0.039035
# reconstruction_error_train : 30.940380
# reconstruction_error_valid : 30.935823
# accuracy_train : 0.038574
# loss_test : 32.769444
# reconstruction_error_test : 30.926641
# loss_valid : 32.775772
# loss_train : 32.783642
# epoch : 80.000000
# accuracy_valid : 0.039631
# accuracy_test : 0.038916
# reconstruction_error_train : 30.939322
# reconstruction_error_valid : 30.934755
# accuracy_train : 0.037990
# loss_test : 32.769295
# reconstruction_error_test : 30.916348
# loss_valid : 32.776512
# loss_train : 32.784203
# epoch : 100.000000
# accuracy_valid : 0.039949
# accuracy_test : 0.038916
# reconstruction_error_train : 30.929115
# reconstruction_error_valid : 30.924519
# accuracy_train : 0.037990
# loss_test : 32.769199
# reconstruction_error_test : 30.912539
# loss_valid : 32.776142
# loss_train : 32.784374
# epoch : 120.000000
# accuracy_valid : 0.039790
# accuracy_test : 0.038916
# reconstruction_error_train : 30.925341
# reconstruction_error_valid : 30.920731
# accuracy_train : 0.038521
# loss_test : 32.768967
# reconstruction_error_test : 30.917076
# loss_valid : 32.776749
# loss_train : 32.784130
# epoch : 140.000000
# accuracy_valid : 0.039631
# accuracy_test : 0.038797
# reconstruction_error_train : 30.929831
# reconstruction_error_valid : 30.925240
# accuracy_train : 0.038521
# loss_test : 32.769173
# reconstruction_error_test : 30.929241
# loss_valid : 32.776249
# loss_train : 32.783424
# epoch : 160.000000
# accuracy_valid : 0.039631
# accuracy_test : 0.038916
# reconstruction_error_train : 30.941908
# reconstruction_error_valid : 30.937359
# accuracy_train : 0.038574
# loss_test : 32.769184
# reconstruction_error_test : 30.914345
# loss_valid : 32.777248
# loss_train : 32.784370
# epoch : 180.000000
# accuracy_valid : 0.039631
# accuracy_test : 0.039035
# reconstruction_error_train : 30.927124
# reconstruction_error_valid : 30.922535
# accuracy_train : 0.038362
# loss_test : 32.770031
# reconstruction_error_test : 30.913668
# loss_valid : 32.776409
# loss_train : 32.784290
# epoch : 200.000000
# accuracy_valid : 0.039790
# accuracy_test : 0.038797
# reconstruction_error_train : 30.926455
# reconstruction_error_valid : 30.921856
# accuracy_train : 0.038521
# loss_test : 32.769192
# reconstruction_error_test : 30.921846
# loss_valid : 32.776478
# loss_train : 32.784237
# epoch : 220.000000
# accuracy_valid : 0.039790
# accuracy_test : 0.038797
# reconstruction_error_train : 30.934570
# reconstruction_error_valid : 30.930000
# accuracy_train : 0.038627
# loss_test : 32.769295
# reconstruction_error_test : 30.923634
# loss_valid : 32.775959
# loss_train : 32.783985
# epoch : 240.000000
# accuracy_valid : 0.039631
# accuracy_test : 0.039035
# reconstruction_error_train : 30.936340
# reconstruction_error_valid : 30.931776
# accuracy_train : 0.039104
# loss_test : 32.769054
# reconstruction_error_test : 30.929871
# loss_valid : 32.775932
# loss_train : 32.783615
# epoch : 260.000000
# accuracy_valid : 0.039790
# accuracy_test : 0.039990
# reconstruction_error_train : 30.942522
# reconstruction_error_valid : 30.937967
# accuracy_train : 0.038627
# loss_test : 32.769161
# reconstruction_error_test : 30.929642
# loss_valid : 32.776310
# loss_train : 32.783680
# epoch : 280.000000
# accuracy_valid : 0.039472
# accuracy_test : 0.039035
# reconstruction_error_train : 30.942310
# reconstruction_error_valid : 30.937767
# accuracy_train : 0.038627
# loss_test : 32.769032
# reconstruction_error_test : 30.925625
# loss_valid : 32.775345
# loss_train : 32.783428
# epoch : 300.000000
# accuracy_valid : 0.039631
# accuracy_test : 0.039035
# reconstruction_error_train : 30.938320
# reconstruction_error_valid : 30.933760
# accuracy_train : 0.038839
# loss_test : 32.769306
# reconstruction_error_test : 30.939178
# loss_valid : 32.776463
# loss_train : 32.784309
# epoch : 320.000000
# accuracy_valid : 0.039790
# accuracy_test : 0.039632
# reconstruction_error_train : 30.951763
# reconstruction_error_valid : 30.947243
# accuracy_train : 0.039157
# loss_test : 32.769226
# reconstruction_error_test : 30.932478
# loss_valid : 32.776524
# loss_train : 32.783546
# epoch : 340.000000
# accuracy_valid : 0.039631
# accuracy_test : 0.039990
# reconstruction_error_train : 30.945112
# reconstruction_error_valid : 30.940569
# accuracy_train : 0.038627
# loss_test : 32.768974
# reconstruction_error_test : 30.917772
# loss_valid : 32.776703
# loss_train : 32.783733
# epoch : 360.000000
# accuracy_valid : 0.039631
# accuracy_test : 0.039155
# reconstruction_error_train : 30.930508
# reconstruction_error_valid : 30.925919
# accuracy_train : 0.038521
# loss_test : 32.769409
# reconstruction_error_test : 30.909624
# loss_valid : 32.776096
# loss_train : 32.784500
# epoch : 380.000000
# accuracy_valid : 0.039790
# accuracy_test : 0.038797
# reconstruction_error_train : 30.922441
# reconstruction_error_valid : 30.917818

# %%
# Build the stats for plots

splits = ("train", "valid", "test")

def get_stats(experiment, stat_names):
    stats = {}
    for spl in splits:
        stats[spl] = {}
        for v in stat_names:
            stats[spl][v] = [stat[v + "_" + spl] for stat in experiment.stats]
    return stats

def plot_stat(stats, stat_name):
    for spl in splits:
        plt.plot(stats[spl][stat_name], label="%s %s" % (spl, stat_name))
    plt.legend(bbox_to_anchor=(0.5, 1.05))
    plt.xlabel("epoch")



    
stat_names = ["accuracy", "loss", "reconstruction_error"]
stats = get_stats(reconstruct_previous_layer_experiments[0], stat_names)

# %%
plot_stat(stats, "accuracy")
plt.show()

# %%
plot_stat(stats, "reconstruction_error")
plt.show()

# %%
plot_stat(stats, "loss")
plt.show()

# %%
#get the weights of each layer
weights = []
for exp in reconstruct_previous_layer_experiments:
    all_params = lasagne.layers.get_all_params(exp.l_x_hat)
    W = all_params[1].get_value().T # get te weight matrix
    weights.append(W)

#build the visualizations of each layer
vis = build_visualizations_by_weighted_combinations(weights, until_layer=len(reconstruct_previous_layer_experiments)-1, top=0.01)

# %%
# une qui genere le visualisations recursivement : le visualisation d'une unité A du layer N
# est la moyenne des visualizations de X unités du layer N - 1 avec lesquelles
#  l'unité A a la plus grosse connectivité (en termes de poids reliant A aux couches du layer precedent)
# La deuxieme méthode prend la moyenne des top X examples qui maximisent l'activation de l'unité

# ?? Peut-on échantillonner et afficher les échantillons? Faut éventuellement les faire.

# Visualize the first layer
grid_plot(vis[0], imshow_options={"cmap": "gray"}, nbrows=20, nbcols=20, random=False)
plt.show()

# %%
reconstruct_previous_layer_experiments[0].post_show_reconstructions(nb=10)

# %%
# visualize the second layer (if available)
grid_plot(vis[1], imshow_options={"cmap": "gray"}, nbrows=10, nbcols=10, random=True)
plt.show()

# %%
# visualize the third layer (if available)
grid_plot(vis[2], imshow_options={"cmap": "gray"}, nbrows=10, nbcols=10, random=True)
plt.show()

# %%
# Compute the representations of each layer for 'test' dataset
dataset = datasets['test']
X = dataset.X.get_value()
representations = [X]
for exp in reconstruct_previous_layer_experiments:
    X = exp.get_code(X)
    representations.append(X)

# %%
import pandas as pd

# Plot the distributions of the representation of a given layer
# Randomly selection of a set of features in the representation and
# plot in a grid the following:
# - For non-diagonal locations, plot relationship between two features
# - For diagonal ones, plot the histogram of a feature
# The id of the selected features is in "selected_features"

# If we want "easy" sampling with auto-encoders, we need the last layer to be uniform...

layer = 0
representation = representations[layer]

selected_features = np.random.randint(0, representation.shape[1] - 1, size=5)

reprenstation = pd.DataFrame(representation)
g = sbn.PairGrid(reprenstation, vars=selected_features)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()

# %%
# or we can model the last layer representation using an RBM (a simple one if possible)...

from sklearn.neural_network.rbm import BernoulliRBM
representation = representations[-1]
print reprenstation.shape
model = BernoulliRBM(n_components=80, n_iter=100)
model.fit(representation)

def sample_from_rbm(rbm, nb_examples, nb_iterations=10):
    nb_features = rbm.components_.shape[1]
    v = np.random.uniform(size=(nb_examples, nb_features))
    for i in xrange(nb_iterations):
        v = rbm.gibbs(v)
    return v
# Out:
# (100, 784)

# %%
# The sampling  part


nb_examples = 50 # nb of examples to sample
nb_iterations = 150 # nb of gibbs iterations

# sample from RBM
X = sample_from_rbm(model, nb_examples, nb_iterations)

# go back to the input layer
for exp in reversed(reconstruct_previous_layer_experiments):
    X  = exp.get_reconstruction_from_code(X)

# %%
# Show the samples
grid_plot(lasagne.easy.get_2d_square_image_view(X))

# %%
# Correlation matrix between a layer of representation and params that generate the data (translation, scale, rotation) in case InfiniteMnistDataset is used

layer_to_study = 4
corr = np.corrcoef(representations[layer_to_study].T, datasets['test'].X_params.T)
corr = corr[0:representations[i].shape[1], representations[i].shape[1]:]
sbn.heatmap(corr)
plt.show()

# On rows : features of the representation layer
# On cols : features of the params that generate the data
# ---> Discard  cols 3 and 4, they represent scale of x and y, the value of these features 
#      is always constant because we don't change the scale of the images

# %%
#Show the effect of changing a feature on a layer (typically the topest layer) with respect to the input layer
import matplotlib.animation as animation
# Use the last layer as starting point
repr_start = len(representations) - 1
# browse different values for this feature in the layer
browse_feature = 2

X = representations[repr_start]

min_feat = min(X[:, browse_feature])
max_feat = max(X[:, browse_feature])
fig  = plt.figure()
nb_bins = 100
ims = []
for i in xrange(nb_bins):
    
    X = representations[repr_start].copy()
    value_for_feat = min_feat + (max_feat - min_feat) * float(i)/nb_bins
    X[:, browse_feature] = value_for_feat
    # get back to the input
    for exp in reversed(reconstruct_previous_layer_experiments[0:repr_start]):
        X  = exp.get_reconstruction_from_code(X)
    
    #grid_plot(easy.get_2d_square_image_view(X))
    X_im = easy.get_2d_square_image_view(X)
    ims.append([plt.imshow(X_im[30])])


print len(ims)
ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
    repeat_delay=1000)
ani.save("video.gif")
plt.show()
# Out:
# 100
# /home/gridcl/mehdicherti/anaconda/lib/python2.7/site-packages/matplotlib/animation.py:727: UserWarning: MovieWriter ffmpeg unavailable
#   warnings.warn("MovieWriter %s unavailable" % writer)

# %%
from IPython.display import Image
Image(url='video.gif')
# Out:
# <img src="video.gif"/>

# %%
import matplotlib.animation as animation

image_from = 25
image_to = 47
ds = datasets['test']
repr_start = len(representations) - 5

print( np.argmax(ds.y.get_value()[image_from] ), np.argmax(ds.y.get_value()[image_to]))

fig  = plt.figure()

interval = np.arange(0, 1, 0.01)
nb_images = len(interval)
images = np.zeros( (nb_images, ds.X.get_value().shape[1]) )
i = 0
anim = []
for alpha in interval:
    R = (1 - alpha) * representations[repr_start][image_from] + (alpha) * representations[repr_start][image_to]
    
    X = R[np.newaxis, :].copy()
    # get back to the input
    for exp in reversed(reconstruct_previous_layer_experiments[0:repr_start]):
        X  = exp.get_reconstruction_from_code(X)
    images[i] = X
    anim.append([plt.imshow( lasagne.easy.get_2d_square_image_view(X)[0] )])

    i += 1

ani = animation.ArtistAnimation(fig, anim, interval=50, blit=True, repeat_delay=1000)
ani.save("morphing.gif")
# Out:
# (13, 13)

# %%
grid_plot(lasagne.easy.get_2d_square_image_view(images))

# %%
from IPython.display import Image
Image(url='morphing.gif')
# Out:
# <img src="morphing.gif"/>

# %%
grid_plot(lasagne.easy.get_2d_square_image_view(datasets['test'].X.get_value()), nbrows=12, nbcols=10, random=False)
