# %%
# %load_ext autoreload

# %autoreload

import pylearn2
from pylearn2.utils import serial

from pylearn2.datasets.fonts import Fonts
import theano
import numpy as np

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = serial.load("model.pkl")
data = Fonts(kind='all', accept_only='(.*)-[abcdxyz]-(.*)', labels_kind='letters')
#data = Fonts(kind='all')
labels = data.y
data = data.X.astype(np.float32)
# Out:
# (9019, 1) [[ 1]
#  [ 0]
#  [ 2]
#  ...,
#  [25]
#  [ 0]
#  [23]]
# (9019, 256)

# %%
print data.shape
# Out:
# (9019, 256)

# %%
X = model.get_input_space().make_theano_batch()
X_code = model.encode(X)
X_hat = model.decode(X_code)


get_code = theano.function([X], X_code)
get_reconstruction = theano.function([X], X_hat)
decode = theano.function([X_code], X_hat)

# %%
data_reconstruction = get_reconstruction(data)
data_code = get_code(data)
l = int(np.sqrt(data.shape[1]))
w, h = l, l
data_img = data.reshape( (data.shape[0], w, h) )
data_reconstruction_img= data_reconstruction.reshape( data_img.shape )

# %%
#Reconstructions

n = 10

for i in xrange(n):
    k = np.random.randint(0, data.shape[0] - 1)
    plt.subplot(n, 2, 2 * i + 1)
    plt.axis('off')
    plt.imshow(data_img[k], cmap='gray')
    plt.subplot(n, 2, 2 * i + 2)
    plt.axis('off')
    plt.imshow(data_reconstruction_img[k], cmap='gray')


plt.show()

# %%
N = 1000
pca = PCA(n_components=2)
pca.fit(data)
data_2d_from_orig = pca.transform(data[0:N])
labels = labels[0:N]
pca = PCA(n_components=2)
pca.fit(data_code)
data_2d_from_codes = pca.transform(data_code[0:N])

# %%
print data_code.shape
plt.subplot(1, 2, 1)
plt.scatter(data_2d_from_orig[:, 0], data_2d_from_orig[:, 1], c=labels[:, 0])
plt.subplot(1, 2, 2)
plt.scatter(data_2d_from_codes[:, 0], data_2d_from_codes[:, 1], c=labels[:, 0])
plt.show()
# Out:
# (9019, 50)

# %%
# Generation as interpolation
def generate(nb_examples, data_code, sparsity=0.999):
    weights = np.random.uniform( size=(nb_examples, data_code.shape[0]) )
    masks = np.random.uniform( size = weights.shape ) <= (1 - sparsity)
    weights = weights * masks
    weights = weights / (weights.sum(axis=1)[:, np.newaxis])
    examples_codes = np.dot(weights, data_code).astype(np.float32)
    return decode(examples_codes)


nb = 32
per_dim = int(np.sqrt(nb))
generated = generate(nb, data_code)
generated_img = generated.reshape( (generated.shape[0], data_img.shape[1], data_img.shape[2] ) )
k = 1
for y in xrange(per_dim):
    for x in xrange(per_dim):
        plt.subplot(per_dim, per_dim, k)
        plt.axis('off')
        plt.imshow(generated_img[k - 1], cmap='gray')
        k += 1
plt.show()

# %%
plt.imshow(W.T, cmap='cool')
plt.show()
print W
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c98c19032f36> in <module>()
# ----> 1 plt.imshow(W.T, cmap='cool')
#       2 plt.show()
#       3 print W
#
# NameError: name 'W' is not defined

# %%
model_supervised = serial.load("model_supervised.pkl")
L = model_supervised.layers[0]
W, b = L.get_params()
W = W.get_value()
s = 5
k = 1
for y in xrange(s):
    for x in xrange(s):
        plt.subplot(s, s, k)
        #plt.imshow(((W[:,k - 1])).reshape( (16, 16) ), cmap='gray')
        plt.imshow((W[k - 1, 0]), cmap='gray', interpolation="nearest")
        k += 1
plt.show()

#data = Fonts(kind='all', accept_only='(.*)-a-(.*)')
#data = Fonts(kind='all')
#abels = data.y
#data = data.X.astype(np.float32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-233-57f49e366d45> in <module>()
#       9         plt.subplot(s, s, k)
#      10         #plt.imshow(((W[:,k - 1])).reshape( (16, 16) ), cmap='gray')
# ---> 11         plt.imshow((W[k - 1, 0]), cmap='gray', interpolation="nearest")
#      12         k += 1
#      13 plt.show()
#
# /home/gridcl/mehdicherti/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, **kwargs)
#    2953                         vmax=vmax, origin=origin, extent=extent, shape=shape,
#    2954                         filternorm=filternorm, filterrad=filterrad,
# -> 2955                         imlim=imlim, resample=resample, url=url, **kwargs)
#    2956         draw_if_interactive()
#    2957     finally:
#
# /home/gridcl/mehdicherti/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    4628                        filterrad=filterrad, resample=resample, **kwargs)
#    4629
# -> 4630         im.set_data(X)
#    4631         im.set_alpha(alpha)
#    4632         if im.get_clip_path() is None:
#
# /home/gridcl/mehdicherti/anaconda/lib/python2.7/site-packages/matplotlib/image.pyc in set_data(self, A)
#     432         if (self._A.ndim not in (2, 3) or
#     433             (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 434             raise TypeError("Invalid dimensions for image data")
#     435
#     436         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %%
from pylearn2.scripts import plot_weights
# %autoreload
act = X
activations = []
for autoencoder in model.autoencoders:
    act = autoencoder.encode(act)
    activations.append(act)

get_activations = theano.function([X], activations)

layers = get_activations(data)

# %%
vis = plot_weights.build_visualizations_by_averaging_inputs_maximizing_activations(
    data, layers[0], top=0.01
)

# %%
plot_weights.grid_plot(vis, nbrows=8, nbcols=8, imshow_options={'cmap': 'gray'})
plt.show()

# %%
weights = [autoencoder.get_params()[2].get_value().T for autoencoder in model.autoencoders]
visualizations = plot_weights.build_visualizations_by_weighted_combinations(weights, until_layer=0)

# %%
plot_weights.grid_plot(visualizations[0], imshow_options={"cmap": "gray"},random=False)

# %%
print data_code.mean(axis=0)
# Out:
# [ 0.40203315  0.38532639  0.3942551   0.39070126  0.45109794  0.41472515
#   0.40980434  0.445492    0.37012687  0.43876955  0.42052516  0.42955741
#   0.36929879  0.44611108  0.369358    0.42101973  0.41582108  0.51350385
#   0.40679607  0.41667193  0.4762468   0.43662179  0.43156391  0.42905825
#   0.39364415  0.43451962  0.47594687  0.38250616  0.45834765  0.43650714
#   0.46859008  0.39879534  0.4805961   0.43001041  0.37731442  0.40295246
#   0.40102628  0.40957341  0.52944189  0.39866552  0.439482    0.46626359
#   0.44841066  0.40319493  0.4182092   0.33318365  0.45190343  0.39508432
#   0.43016526  0.42022628]
